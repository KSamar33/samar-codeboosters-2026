# %%
# !pip install groq --quiet

import os
import json
import re
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print('Libraries ready')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 2.2 MB/s eta 0:00:00
# Libraries ready

# %%
from groq import Groq
API_KEY = "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"
client = Groq(api_key=API_KEY)
MODEL = "llama-3.1-8b-instant"

print(f'Groq client configured with model: {MODEL}')
print('Make sure API_KEY is replaced with your actual key!')
# Out:
# Groq client configured with model: llama-3.1-8b-instant
# Make sure API_KEY is replaced with your actual key!

# %%
def ask_llm(user_message, system_message="You are a helpful assistaant.", temperature = 0.7, max_tokens = 500):
  response = client.chat.completions.create(
      model = MODEL,
      messages = [
        {
          "role": "system","content": system_message
        },
        {
          "role": "user","content": user_message
        }
      ],
      temperature = temperature,
      max_tokens = max_tokens,

  )

  return response.choices[0].message.content

text_response = ask_llm(
    "Bumrah vs Starc"
)
print('===LLM Response===')
print(text_response)
# Out:
# ===LLM Response===
# Jasprit Bumrah and Mitchell Starc are two of the most skilled fast bowlers in international cricket. Here's a comparison between the two:
#
# **Jasprit Bumrah**
#
# - **Nationality:** Indian
# - **Birthdate:** December 6, 1993
# - **Batting Style:** Right-handed
# - **Bowling Style:** Right-arm fast-medium
# - **Career Stats:** In international cricket, Bumrah has taken 155 wickets in 57 ODI matches and 93 wickets in 43 Test matches.
# - **Key Strengths:** Bumrah is known for his incredible swing and reverse swing, which makes him a nightmare for batsmen. His ability to bowl yorkers and short balls at high speed is also a strength.
#
# **Mitchell Starc**
#
# - **Nationality:** Australian
# - **Birthdate:** January 30, 1990
# - **Batting Style:** Right-handed
# - **Bowling Style:** Left-arm fast
# - **Career Stats:** In international cricket, Starc has taken 242 wickets in 104 ODI matches and 254 wickets in 73 Test matches.
# - **Key Strengths:** Starc is a powerful fast bowler with the ability to bowl at speeds of over 150 km/h. His ability to bowl inswingers and bouncers is also a strength.
#
# **Comparison**
#
# Both Bumrah and Starc are among the best fast bowlers in the world. However, their styles are different. Bumrah is a more skilled bowler in terms of swing and reverse swing, while Starc is a more powerful bowler with the ability to bowl at high speeds.
#
# **Head-to-Head Record**
#
# The head-to-head record between Bumrah and Starc is limited, but in the 4 matches they have played each other, Starc has taken 5 wickets, while Bumrah has taken 4 wickets.
#
# **Conclusion**
#
# Both Bumrah and Starc are excellent fast bowlers with unique strengths. While Bumrah is a more skilled bowler in terms of swing and reverse swing, Starc is a more powerful bowler with the ability to bowl at high speeds. Ultimately, the choice between the two will depend on the specific conditions and the batsmen they are facing.

# %%
response_etl = ask_llm(
    "In 3 bullet points, explain how Medallion Architecture"
    "(Bronze, Silver, Gold layers) relates to ETL pipelines.",
    system_message="You are a senior data engineering instructor."
    "Be concise and practical."
)
print('Medallion + ETL connection:')
print(response_etl)
print()
print('--- Token explanation ---')
print('Each word is roughly 1-2 tokens.')
print('The model above used approximately', len(response_etl.split())*1.3,'tokens.')
print('Llama-3.1-8b context window: 8192 tokens (~6000 words per conversation)')
# Out:
# Medallion + ETL connection:
# Here's how Medallion Architecture (Bronze, Silver, Gold layers) relates to ETL pipelines:
#
# • **Bronze Layer**: This layer is equivalent to the **Ingestion Layer** in ETL pipelines. It's responsible for collecting and storing raw data from various sources, often in a NoSQL or semi-structured format (e.g., JSON, CSV).
#
# • **Silver Layer**: This layer is similar to the **Data Warehousing Layer** or **Staging Layer** in ETL pipelines. It involves transforming and aggregating the raw data from the Bronze layer, applying data quality checks, and creating a unified view of the data to facilitate analysis.
#
# • **Gold Layer**: This layer is analogous to the **Reporting and Analytics Layer** in ETL pipelines. It's where the transformed and aggregated data is used to create meaningful insights, often in a data visualization or reporting format, using tools like data visualization software, business intelligence platforms, or data science frameworks.
#
# --- Token explanation ---
# Each word is roughly 1-2 tokens.
# The model above used approximately 184.6 tokens.
# Llama-3.1-8b context window: 8192 tokens (~6000 words per conversation)

# %%
response_etl = ask_llm(
    "What is Gen AI",
    system_message="You are a senior AI engineer must explain in a technical way"
)
print('Medallion + ETL connection:')
print(response_etl)
print()
print('--- Token explanation ---')
print('Each word is roughly 1-2 tokens.')
print('The model above used approximately', len(response_etl.split())*1.3,'tokens.')
print('Llama-3.1-8b context window: 1500 tokens (~6000 words per conversation)')
# Out:
# Medallion + ETL connection:
# As a senior AI engineer, I'm happy to explain the concept of General Artificial Intelligence (Gen AI) in a technical way.
#
# **Definition:**
# General Artificial Intelligence (Gen AI) refers to a hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. Gen AI is a type of artificial intelligence that can perform any intellectual task that a human can, with the same level of competence and creativity.
#
# **Key Characteristics:**
#
# 1. **Autonomy**: Gen AI is self-directed and can make decisions without human intervention.
# 2. **General Knowledge**: Gen AI has a broad understanding of knowledge and can apply it to various domains.
# 3. **Reasoning**: Gen AI can reason and draw conclusions based on available information.
# 4. **Learning**: Gen AI can learn from experiences and adapt to new situations.
# 5. **Creativity**: Gen AI can generate novel solutions and ideas.
# 6. **Common Sense**: Gen AI has a deep understanding of the world and can apply common sense to problem-solving.
#
# **Technical Requirements:**
#
# To achieve Gen AI, the following technical requirements must be met:
#
# 1. **Cognitive Architectures**: A cognitive architecture is a theoretical framework that describes how the mind processes information. Gen AI requires a robust cognitive architecture that integrates perception, attention, memory, reasoning, and decision-making.
# 2. **Knowledge Representation**: Gen AI requires a robust knowledge representation system that can store, retrieve, and manipulate large amounts of knowledge.
# 3. **Machine Learning**: Gen AI relies heavily on machine learning algorithms that can learn from data and improve performance over time.
# 4. **Neural Networks**: Neural networks are a key component of Gen AI, enabling the system to learn complex patterns and relationships in data.
# 5. **Integration**: Gen AI requires the integration of multiple AI systems and tools, such as natural language processing, computer vision, and robotics.
#
# **Current State:**
# While we have made significant progress in developing AI systems, we are still far from achieving true Gen AI. Currently, AI systems are narrow or specialized, meaning they are designed to perform a specific task, such as image recognition or language translation. However, researchers are actively working on developing more general-purpose AI systems that can learn and adapt to a wide range of tasks.
#
# **Challenges:**
# Achieving Gen AI is a complex and challenging task that requires significant advances in multiple areas, including:
#
# 1. **Cognitive Architectures**: Developing a
#
# --- Token explanation ---
# Each word is roughly 1-2 tokens.
# The model above used approximately 504.40000000000003 tokens.
# Llama-3.1-8b context window: 1500 tokens (~6000 words per conversation)

# %%
zero_shot_response = ask_llm(
    "Extract the city name from this address: "
    "456 Brigade Road, Bangalore 560025, Karnataka, India"
)
print('Zero-Shot Result:')
print(zero_shot_response)
print()

ambiguous_response = ask_llm("Clean this data: ramesh kumar,45000,mumbai")
print('Ambiguous Zero-Shot Result:')
print(ambiguous_response)
print()
print('Problem: output format is unpredictable and not machine-parseable!')
# Out:
# Zero-Shot Result:
# The city name is: Bangalore.
#
# Ambiguous Zero-Shot Result:
# It appears that the data is a comma-separated list of values, but it's not properly formatted. Assuming you want to break it down into individual fields, here's the cleaned data:
#
# - Name: Ramesh Kumar
# - Salary: 45,000
# - Location: Mumbai
#
# Problem: output format is unpredictable and not machine-parseable!

# %%
zero_shot_response = ask_llm(
    "Extract the city name from this address: "
    "student_performance.csv"
)
print('Zero-Shot Result:')
print(zero_shot_response)
print()

ambiguous_response = ask_llm("Clean this data:")
print('Ambiguous Zero-Shot Result:')
print(ambiguous_response)
print()
print('Problem: output format is unpredictable and not machine-parseable!')
# Out:
# Zero-Shot Result:
# The department from the address "student_performance.csv" would be "csv" which corresponds to the "Comma Separated Values" file format.
#
# Ambiguous Zero-Shot Result:
# I'm ready to help. What data do you need cleaned? Is it a text, a list, a spreadsheet, or something else?
#
# Problem: output format is unpredictable and not machine-parseable!

# %%
few_shot_prompt="""
Convert employee tesxt to JSON. Here are example:

Input : RAMESH KUMAR, 4500, Mumbai
Output : {"name": "RAMESH KUMAR", "salary": 4500, "city": "Mumbai"}

Input : ANISHA , 5000, Mumbai
Output : {"name": "ANISHA", "salary": 5000, "city": "Mumbai"}
"""

few_shot_response = ask_llm(few_shot_prompt, temperature=0.0)
print('Few-Shot Result:')
print(few_shot_response)
print()

try:
  parsed =json.loads(few_shot_response.strip())
  print('Succesfully parsed as JSON!')
  print(f'Name: {parsed["name"]}')
  print(f'Salary: {parsed["salary"]}')
  print(f'City: {parsed["city"]}')
except json.JSONDecodeError:
  print('Parsing failed - model added extra text')
  print('Solution: add explicit instructions int the system prompt')
# Out:
# Few-Shot Result:
# Here's a Python function that can convert the employee text to JSON:
#
# ```python
# import json
#
# def employee_to_json(employee_text):
#     """
#     Convert employee text to JSON.
#
#     Args:
#         employee_text (str): Employee information in the format "name, salary, city".
#
#     Returns:
#         dict: Employee information in JSON format.
#     """
#     # Split the employee text into individual values
#     values = employee_text.split(", ")
#
#     # Create a dictionary with the employee information
#     employee_info = {
#         "name": values[0],
#         "salary": int(values[1]),
#         "city": values[2]
#     }
#
#     # Convert the dictionary to JSON
#     employee_json = json.dumps(employee_info)
#
#     return employee_json
#
# # Example usage:
# employee_text1 = "RAMESH KUMAR, 4500, Mumbai"
# employee_text2 = "ANISHA, 5000, Mumbai"
#
# print(employee_to_json(employee_text1))
# print(employee_to_json(employee_text2))
# ```
#
# When you run this code, it will output:
#
# ```json
# {"name": "RAMESH KUMAR", "salary": 4500, "city": "Mumbai"}
# {"name": "ANISHA", "salary": 5000, "city": "Mumbai"}
# ```
#
# This function assumes that the input text is in the correct format and that the salary is a valid integer. If the input text is not in the correct format, the function may raise an error or produce incorrect results. You may want to add error checking code to handle these cases.
#
# Parsing failed - model added extra text
# Solution: add explicit instructions int the system prompt

# %%
same_question = """Review the following Python code for potential issues:\n\ndef process_data(data_list):\n    result = []\n    for item in data_list:\n        result.append(item * 2)\n    return result\n\nprint(process_data([1, 2, '3']))\n"""
generic_response = ask_llm(same_question, temperature = 0.2)
print('Without Role Prompting:')
print(generic_response[:300],'...')
print()

role_response = ask_llm(
    same_question,
    system_message = "You are a senior data engineer with 10 years of production."
                      "experience. Review code critically for production readiness,"
                      "data type issues, and potential failures at scale.",
    temperature = 0.2
)
print('With Role Prompting:(Senior Data Engineer)')
print(role_response[:400],'...')
print()
print('Notice: role prompting produces more technical, actionable feedback')
# Out:
# Without Role Prompting:
# The provided Python code appears to be a simple function that takes a list of data, doubles each item in the list, and returns the new list. However, there are a few potential issues with this code:
#
# 1. **Type Checking**: The function does not check the type of the input data. If the input is not a  ...
#
# With Role Prompting:(Senior Data Engineer)
# **Code Review**
#
# The provided Python code appears to be a simple function that doubles each element in a list. However, there are several potential issues that need to be addressed for production readiness:
#
# ### 1. Data Type Issues
#
# The function does not handle different data types. If the input list contains non-numeric values (e.g., strings, booleans), the function will raise a TypeError when tr ...
#
# Notice: role prompting produces more technical, actionable feedback

# %%
prompt = "Give me one creative name for a data analytics startup"

print('===Temperature Experiment===')
for temp in[0.0, 0.5, 1.0]:
  response = ask_llm(prompt, temperature = temp)
  print(f'Temperature {temp}: {response.strip()}')
  time.sleep(1)

  print()
  print('Observation:')
  print('temperature = 0.0 -> Same or very similar answer every run (deterministic)')
  print('temperature = 0.5 -> some variations')
  print('temperature = 1.0 -> more creative/varied, sometimes surprising')
  print()
  print('Rule for data engineering tasks: use temperature = 0.0 or 0.1')
  print('You need CONSISTENT, PARSEABLE output - not creative variation')
# Out:
# ===Temperature Experiment===
# Temperature 0.0: Here's a creative name for a data analytics startup:
#
# **Nexa Insights**
#
# "Nexa" suggests connection and linkages, implying the ability to connect disparate data points and provide valuable insights. This name conveys a sense of innovation and forward-thinking, which is perfect for a data analytics startup.
#
# Observation:
# temperature = 0.0 -> Same or very similar answer every run (deterministic)
# temperature = 0.5 -> some variations
# temperature = 1.0 -> more creative/varied, sometimes surprising
#
# Rule for data engineering tasks: use temperature = 0.0 or 0.1
# You need CONSISTENT, PARSEABLE output - not creative variation
# Temperature 0.5: Here's a creative name for a data analytics startup:
#
# **Nexio Insights**
#
# "Nxio" is derived from the word "nexus," implying connection and integration, which is fitting for a data analytics startup that helps businesses connect the dots between their data and insights. The word "Insights" clearly communicates the company's focus on providing valuable and actionable information to its clients.
#
# Observation:
# temperature = 0.0 -> Same or very similar answer every run (deterministic)
# temperature = 0.5 -> some variations
# temperature = 1.0 -> more creative/varied, sometimes surprising
#
# Rule for data engineering tasks: use temperature = 0.0 or 0.1
# You need CONSISTENT, PARSEABLE output - not creative variation
# Temperature 1.0: Here's a creative name for a data analytics startup:
#
# "Nexia Insights"
#
# The name "Nexia" is derived from the word "nexus," which means a connection or link, reflecting the startup's focus on connecting data points and providing insightful analysis. This name suggests that the company helps customers make sense of their data by identifying connections and patterns, making informed decisions easier.
#
# Observation:
# temperature = 0.0 -> Same or very similar answer every run (deterministic)
# temperature = 0.5 -> some variations
# temperature = 1.0 -> more creative/varied, sometimes surprising
#
# Rule for data engineering tasks: use temperature = 0.0 or 0.1
# You need CONSISTENT, PARSEABLE output - not creative variation

# %%
messy_invoices  = [
    "INV-2024-0891 TECHWORLD SOLUTIONS 15TH JAN 2024 Rs. 45,000 Laptop Purchase",
    "Invoice from PRIYA ENTERPRISES dt 07-02-2024 amt:12500 for Office Cleaning Services",
    "#INV-2024-103",
    "Tax Invoice: Ananya Tech Solution"
]
print('Messy invoices to process:')
for i, inv in enumerate(messy_invoices, 1):
  print(f'{i}. {inv}')
print(f'\nTotal: {len(messy_invoices)} invoices')
# Out:
# Messy invoices to process:
# 1. INV-2024-0891 TECHWORLD SOLUTIONS 15TH JAN 2024 Rs. 45,000 Laptop Purchase
# 2. Invoice from PRIYA ENTERPRISES dt 07-02-2024 amt:12500 for Office Cleaning Services
# 3. #INV-2024-103
# 4. Tax Invoice: Ananya Tech Solution
#
# Total: 4 invoices

# %%
EXTRACTION_SYSTEM_PROMPT ="""You are an AI assistant specialized in extracting key information from messy invoice texts.Your task is to parse the provided invoice text and extract the following fields into a JSON object:invoice_id: The invoice number (e.g., INV-2024-0891). It might start with # or Tax Invoice.company_name: The name of the company issuing the invoice.issue_date: The date the invoice was issued (e.g., 15th JAN 2024, 07-02-2024, 2024/02/20, 28-Feb-24).amount: The total amount of the invoice. It might be preceded by 'Rs.', 'amt:', 'INR', or just be a number.description: A brief description of the goods or services.Ensure the output is a valid JSON object.If a field is not found, use `null` as its value."""
print('Extraction prompt engineered!')
print(f'System prompt length: {len(EXTRACTION_SYSTEM_PROMPT)} characters')
print(f' = {len(EXTRACTION_SYSTEM_PROMPT.split())} words, = {int(len(EXTRACTION_SYSTEM_PROMPT.split())*1.3)} tokens')
# Out:
# Extraction prompt engineered!
# System prompt length: 696 characters
#  = 109 words, = 141 tokens

# %%
few_shot_name_salary_prompt = """
  Convert employee text to JSON, extracting only 'name' and 'salary'. Here are examples:
  Input: John Doe, 60000 USD
  Output: {"name": "John Doe", "salary": 60000}

  Input: Jane Smith, 75000
  Output: {"name": "Jane Smith", "salary": 75000}

  Input: Alice Brown, 92000 GBP
  Output: {"name": "Alice Brown", "salary": 92000}

  Input: David Lee, 55000
  Output: {"name": "David Lee", "salary": 55000}
"""

name_salary_response = ask_llm(
    few_shot_name_salary_prompt + "Input: Bob Johnson, 80000",
    system_message="You are an assistant that converts employee text to JSON. Only output the JSON and nothing else.",
    temperature = 0.0
)

print('Few-shot Name and Salary Result:')
print(name_salary_response)

try:
  parsed_name_salary = json.loads(name_salary_response.strip())
  print('Successfully parsed JSON')
  print(f'Name: {parsed_name_salary["name"]}, Salary: {parsed_name_salary["salary"]}')
except json.JSONDecodeError:
  print('Parsing failed - model added extra text')
  print('Solution: add explicit instructions in the system prompt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1547/2459216172.py in <cell line: 0>()
#      14 """
#      15
# ---> 16 name_salary_response = ask_llm(
#      17     few_shot_name_salary_prompt + "Input: Bob Johnson, 80000",
#      18     system_message="You are an assistant that converts employee text to JSON. Only output the JSON and nothing else.",
#
# NameError: name 'ask_llm' is not defined
